# %%
from model.linear_regression_direct.linear_regression_class import linear_regression
import numpy as np

# %%
rng = np.random.default_rng()

input_features = rng.standard_normal(100)  
target_values = rng.integers(low=-100, high=100, size=100)

# %%
# create the linear regression class
linear_regression_model = linear_regression(input_features, target_values)

# %%
# generate the model
linear_regression_model.gradient_descent()

# %%
# show the results
linear_regression_model.plots.plot_model_and_traning_set()
linear_regression_model.plots.plot_parameters_path()
