# %%
from model.linear_regression_direct.linear_regression_class import linear_regression
import numpy as np

# %%
rng = np.random.default_rng()

input_features = rng.standard_normal(100)  
target_values = rng.integers(low=-100, high=100, size=100)

# %%
# create the linear regression class
numerical_linear_regression_model = linear_regression(input_features, target_values)
expression_linear_regression_model = linear_regression(input_features, target_values)

# %%
# generate the model
expression_linear_regression_model.gradient_descent(numerically=False)

# %%
numerical_linear_regression_model.gradient_descent(numerically=True)

# %%
# show the results
numerical_linear_regression_model.plots.plot_model_and_traning_set()

# %%
numerical_linear_regression_model.plots.plot_parameters_path()
expression_linear_regression_model.plots.plot_parameters_path()

# %%
print('numerical differentiation for J')
print('------------------------------------')
numerical_linear_regression_model.prints.all()
print('\n')
print('expression for derivative of J')
print('------------------------------------')
expression_linear_regression_model.prints.all()
# Out:
# numerical differentiation for J
# ------------------------------------
# w: 8.883790233085165
# b: -1.3743502177021583
# number of parameters before convergence: 48083
# Final mean squared error: 1707.3772828360254
#
#
# expression for derivative of J
# ------------------------------------
# w: 8.883799889471966
# b: -1.3743518687991145
# number of parameters before convergence: 48084
# Final mean squared error: 1707.377281857175
